# %% [markdown]
# ### Reading and writing images

# %%
# !pip install ipykernel
# !pip install opencv-python
# Out:
# Requirement already satisfied: ipykernel in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (6.25.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ipykernel) (8.16.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (7.2.1)
# Requirement already satisfied: pyzmq>=20 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: backcall in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pickleshare in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\hp\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from exceptiongroup->ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\hp\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2

# %%
# read the image
image = cv2.imread('../image1.png')

# %%
if image is None:
    print('error')
else :
    print('image loaded succesfully')
# Out:
# image loaded succesfully

# %%
# show image
cv2.imshow("image window", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# write an image
read_image = cv2.imread("../output.png")
cv2.imshow('new_image', read_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image2 = read_image + 100
cv2.imwrite('../new2.png', image2)
# Out:
# True

# %% [markdown]
# ### Working with video files

# %%
# load the video
video = cv2.VideoCapture("../video.mp4")

# %%
#display the video
while True:
    ret, frame = video.read()
    if not ret :
        break
    cv2.imshow('video frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video.release()
cv2.destroyAllWindows()

# %%
# writing a video
video = cv2.VideoCapture('../video.mp4')
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('../output.mp4', fourcc, 30,(width,height))

while True:
    ret, frame = video.read()
    if not ret:
        break
    frame =frame + 100
    out.write(frame)
out.release()
video.release()
cv2.destroyAllWindows()
